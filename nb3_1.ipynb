# %%
def hello():
    print("Hello")
    print("bye")


print(hello)

hello()
# Out:
# <function hello at 0x0000011E0B4D98A0>
# Hello
# bye
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 13
#       9
#      10
#      11 a = 10
#      12
# ---> 13 a()
#
# TypeError: 'int' object is not callable
